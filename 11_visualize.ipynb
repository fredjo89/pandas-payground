# %%
# %load_ext lab_black
import pandas as pd
import datetime as dt

file_path = "/Users/fredrikjohannessen/Desktop/repositories/pandas-payground/data/"
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
from pandas_datareader import data
import matplotlib.pyplot as plt

# %% [markdown]
# ### Use the `plot` Method to render a Line Chart

# %%
# The stock price of the company blackberry
bb = data.DataReader(
    name="BB", data_source="stooq", start="2007-01-01", end="2023-03-10"
)
bb.head(3)
# Out:
#             Open  High     Low  Close      Volume
# Date
# 2023-03-09  3.61  3.71  3.5500   3.66  10538001.0
# 2023-03-08  3.51  3.66  3.4292   3.62   7589581.0
# 2023-03-07  3.73  3.74  3.4400   3.50  16164538.0

# %%
bb.plot()
plt.show()

# %%
bb.plot(y=["High", "Open", "Low"])
plt.show()

# %% [markdown]
# ### Modifying plot asthetics with the `matplotlib` package

# %%
plt.style.available
plt.style.use("dark_background")
bb.plot(y=["High", "Open", "Low"])
plt.grid()
plt.show()

# %% [markdown]
# ### Bar Graph

# %%
def rank_performance(stock_price):
    if stock_price <= 10:
        return "Poor"
    elif stock_price <= 50:
        return "Satisfactory"
    else:
        return "Stellar"

# %%
bb["Close"].apply(rank_performance).value_counts().plot(kind="barh")
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Pie Chart

# %%
mean = bb["Close"].mean()


def rank_performance(stock_price):
    if stock_price > mean:
        return "Above average"
    else:
        return "Below Average"


bb["Close"].apply(rank_performance).value_counts().plot(kind="pie", legend=True)
plt.show()
