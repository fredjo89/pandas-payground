# %% [markdown]
# Stying a table is done using the Styler class. <br>
# Under-the-hood, the Styler object uses Cascading Style Sheets (CSS)
#
# Referances: <br>
# [Table Visualization](https://pandas.pydata.org/docs/user_guide/style.html) <br>
# [Blog Post](https://towardsdatascience.com/a-quick-and-easy-guide-to-conditional-formatting-in-pandas-8783035071ee)

# %%
import os
import pandas as pd
import jupyter_black

jupyter_black.load()

current_dir = os.path.dirname(os.path.abspath("__file__"))
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
bond_path = os.path.join(current_dir, "data", "jamesbond.csv")

bond = pd.read_csv(bond_path, index_col="Film")

bond = bond[
    ~((bond.index == "Casino Royale") & (bond["Year"] == 1967))
]  # Dropping the original Casino Royale movie to avoid duplicate indices

bond.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %% [markdown]
# ### The `format` and `format_index` methods

# %%
formatter = {"Box Office": "{:.2f}", "Budget": "{:.2f}", "Bond Actor Salary": "{:.2f}"}

bond.style.format(precision=2).format_index(str.upper, axis=1)
# Out:
# <style type="text/css">
# </style>
# <table id="T_592e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_592e5_level0_col0" class="col_heading level0 col0" >YEAR</th>
#       <th id="T_592e5_level0_col1" class="col_heading level0 col1" >ACTOR</th>
#       <th id="T_592e5_level0_col2" class="col_heading level0 col2" >DIRECTOR</th>
#       <th id="T_592e5_level0_col3" class="col_heading level0 col3" >BOX OFFICE</th>
#       <th id="T_592e5_level0_col4" class="col_heading level0 col4" >BUDGET</th>
#       <th id="T_592e5_level0_col5" class="col_heading level0 col5" >BOND ACTOR SALARY</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Film</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_592e5_level0_row0" class="row_heading level0 row0" >Dr. No</th>
#       <td id="T_592e5_row0_col0" class="data row0 col0" >1962</td>
#       <td id="T_592e5_row0_col1" class="data row0 col1" >Sean Connery</td>
#       <td id="T_592e5_row0_col2" class="data row0 col2" >Terence Young</td>
#       <td id="T_592e5_row0_col3" class="data row0 col3" >448.80</td>
#       <td id="T_592e5_row0_col4" class="data row0 col4" >7.00</td>
#       <td id="T_592e5_row0_col5" class="data row0 col5" >0.60</td>
#     </tr>
#     <tr>
#       <th id="T_592e5_level0_row1" class="row_heading level0 row1" >From Russia with Love</th>
#       <td id="T_592e5_row1_col0" class="data row1 col0" >1963</td>
#       <td id="T_592e5_row1_col1" class="data row1 col1" >Sean Connery</td>
#       <td id="T_592e5_row1_col2" class="data row1 col2" >Terence Young</td>
#       <td id="T_592e5_row1_col3" class="data row1 col3" >543.80</td>
#       <td id="T_592e5_row1_col4" class="data row1 col4" >12.60</td>
#       <td id="T_592e5_row1_col5" class="data row1 col5" >1.60</td>
#     </tr>
#     <tr>
#       <th id="T_592e5_level0_row2" class="row_heading level0 row2" >Goldfinger</th>
#       <td id="T_592e5_row2_col0" class="data row2 col0" >1964</td>
#       <td id="T_592e5_row2_col1" class="data row2 col1" >Sean Connery</td>
#       <td id="T_592e5_row2_col2" class="data row2 col2" >Guy Hamilton</td>
#       <td id="T_592e5_row2_col3" class="data row2 col3" >820.40</td>
#       <td id="T_592e5_row2_col4" class="data row2 col4" >18.60</td>
#       <td id="T_592e5_row2_col5" class="data row2 col5" >3.20</td>
#     </tr>
#     <tr>
#       <th id="T_592e5_level0_row3" class="row_heading level0 row3" >Thunderball</th>
#       <td id="T_592e5_row3_col0" class="data row3 col0" >1965</td>
#       <td id="T_592e5_row3_col1" class="data row3 col1" >Sean Connery</td>
#       <td id="T_592e5_row3_col2" class="data row3 col2" >Terence Young</td>
#       <td id="T_592e5_row3_col3" class="data row3 col3" >848.10</td>
#       <td id="T_592e5_row3_col4" class="data row3 col4" >41.90</td>
#       <td id="T_592e5_row3_col5" class="data row3 col5" >4.70</td>
#     </tr>
#     <tr>
#       <th id="T_592e5_level0_row4" class="row_heading level0 row4" >You Only Live Twice</th>
#       <td id="T_592e5_row4_col0" class="data row4 col0" >1967</td>
#       <td id="T_592e5_row4_col1" class="data row4 col1" >Sean Connery</td>
#       <td id="T_592e5_row4_col2" class="data row4 col2" >Lewis Gilbert</td>
#       <td id="T_592e5_row4_col3" class="data row4 col3" >514.20</td>
#       <td id="T_592e5_row4_col4" class="data row4 col4" >59.90</td>
#       <td id="T_592e5_row4_col5" class="data row4 col5" >4.40</td>
#     </tr>
#     <tr>
#       <th id="T_592e5_level0_row5" class="row_heading level0 row5" >On Her Majesty's Secret Service</th>
#       <td id="T_592e5_row5_col0" class="data row5 col0" >1969</td>
#       <td id="T_592e5_row5_col1" class="data row5 col1" >George Lazenby</td>
#       <td id="T_592e5_row5_col2" class="data row5 col2" >Peter R. Hunt</td>
#       <td id="T_592e5_row5_col3" class="data row5 col3" >291.50</td>
#       <td id="T_592e5_row5_col4" class="data row5 col4" >37.30</td>
#       <td id="T_592e5_row5_col5" class="data row5 col5" >0.60</td>
#     </tr>
#     <tr>
#       <th id="T_592e5_level0_row6" class="row_heading level0 row6" >Diamonds Are Forever</th>
#       <td id="T_592e5_row6_col0" class="data row6 col0" >1971</td>
#       <td id="T_592e5_row6_col1" class="data row6 col1" >Sean Connery</td>
#       <td id="T_592e5_row6_col2" class="data row6 col2" >Guy Hamilton</td>
#       <td id="T_592e5_row6_col3" class="data row6 col3" >442.50</td>
#       <td id="T_592e5_row6_col4" class="data row6 col4" >34.70</td>
#       <td id="T_592e5_row6_col5" class="data row6 col5" >5.80</td>
#     </tr>
#     <tr>
#       <th id="T_592e5_level0_row7" class="row_heading level0 row7" >Live and Let Die</th>
#       <td id="T_592e5_row7_col0" class="data row7 col0" >1973</td>
#       <td id="T_592e5_row7_col1" class="data row7 col1" >Roger Moore</td>
#       <td id="T_592e5_row7_col2" class="data row7 col2" >Guy Hamilton</td>
#       <td id="T_592e5_row7_col3" class="data row7 col3" >460.30</td>
#       <td id="T_592e5_row7_col4" class="data row7 col4" >30.80</td>
#       <td id="T_592e5_row7_col5" class="data row7 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_592e5_level0_row8" class="row_heading level0 row8" >The Man with the Golden Gun</th>
#       <td id="T_592e5_row8_col0" class="data row8 col0" >1974</td>
#       <td id="T_592e5_row8_col1" class="data row8 col1" >Roger Moore</td>
#       <td id="T_592e5_row8_col2" class="data row8 col2" >Guy Hamilton</td>
#       <td id="T_592e5_row8_col3" class="data row8 col3" >334.00</td>
#       <td id="T_592e5_row8_col4" class="data row8 col4" >27.70</td>
#       <td id="T_592e5_row8_col5" class="data row8 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_592e5_level0_row9" class="row_heading level0 row9" >The Spy Who Loved Me</th>
#       <td id="T_592e5_row9_col0" class="data row9 col0" >1977</td>
#       <td id="T_592e5_row9_col1" class="data row9 col1" >Roger Moore</td>
#       <td id="T_592e5_row9_col2" class="data row9 col2" >Lewis Gilbert</td>
#       <td id="T_592e5_row9_col3" class="data row9 col3" >533.00</td>
#       <td id="T_592e5_row9_col4" class="data row9 col4" >45.10</td>
#       <td id="T_592e5_row9_col5" class="data row9 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_592e5_level0_row10" class="row_heading level0 row10" >Moonraker</th>
#       <td id="T_592e5_row10_col0" class="data row10 col0" >1979</td>
#       <td id="T_592e5_row10_col1" class="data row10 col1" >Roger Moore</td>
#       <td id="T_592e5_row10_col2" class="data row10 col2" >Lewis Gilbert</td>
#       <td id="T_592e5_row10_col3" class="data row10 col3" >535.00</td>
#       <td id="T_592e5_row10_col4" class="data row10 col4" >91.50</td>
#       <td id="T_592e5_row10_col5" class="data row10 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_592e5_level0_row11" class="row_heading level0 row11" >For Your Eyes Only</th>
#       <td id="T_592e5_row11_col0" class="data row11 col0" >1981</td>
#       <td id="T_592e5_row11_col1" class="data row11 col1" >Roger Moore</td>
#       <td id="T_592e5_row11_col2" class="data row11 col2" >John Glen</td>
#       <td id="T_592e5_row11_col3" class="data row11 col3" >449.40</td>
#       <td id="T_592e5_row11_col4" class="data row11 col4" >60.20</td>
#       <td id="T_592e5_row11_col5" class="data row11 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_592e5_level0_row12" class="row_heading level0 row12" >Never Say Never Again</th>
#       <td id="T_592e5_row12_col0" class="data row12 col0" >1983</td>
#       <td id="T_592e5_row12_col1" class="data row12 col1" >Sean Connery</td>
#       <td id="T_592e5_row12_col2" class="data row12 col2" >Irvin Kershner</td>
#       <td id="T_592e5_row12_col3" class="data row12 col3" >380.00</td>
#       <td id="T_592e5_row12_col4" class="data row12 col4" >86.00</td>
#       <td id="T_592e5_row12_col5" class="data row12 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_592e5_level0_row13" class="row_heading level0 row13" >Octopussy</t

# %% [markdown]
# ### The `.applymap()` method

# %% [markdown]
# Applies a function to the DataFrame element-wise;

# %%
def highlight_high_box_office(val):
    if type(val) == float and val >= 550:
        bcolor = "yellow"
        color = "black"
        return f"background-color: {bcolor}; color: {color}"
    return ""


def color_actors(val):
    if type(val) != str:
        return ""

    bcolor = {
        "Roger Moore": "green",
        "Sean Connery": "red",
        "Pierce Brosnan": "blue",
        "Daniel Craig": "black",
        "Timothy Dalton": "BlueViolet",
        "George Lazenby": "CornflowerBlue",
    }

    if val in bcolor.keys():
        return f"background-color: {bcolor[val]}"
    return ""


bond.style.applymap(highlight_high_box_office, subset=["Box Office"]).applymap(
    color_actors, subset=["Actor"]
)
# Out:
# <style type="text/css">
# #T_ec944_row0_col1, #T_ec944_row1_col1, #T_ec944_row2_col1, #T_ec944_row3_col1, #T_ec944_row4_col1, #T_ec944_row6_col1, #T_ec944_row12_col1 {
#   background-color: red;
# }
# #T_ec944_row2_col3, #T_ec944_row3_col3, #T_ec944_row21_col3, #T_ec944_row23_col3, #T_ec944_row24_col3 {
#   background-color: yellow;
#   color: black;
# }
# #T_ec944_row5_col1 {
#   background-color: CornflowerBlue;
# }
# #T_ec944_row7_col1, #T_ec944_row8_col1, #T_ec944_row9_col1, #T_ec944_row10_col1, #T_ec944_row11_col1, #T_ec944_row13_col1, #T_ec944_row14_col1 {
#   background-color: green;
# }
# #T_ec944_row15_col1, #T_ec944_row16_col1 {
#   background-color: BlueViolet;
# }
# #T_ec944_row17_col1, #T_ec944_row18_col1, #T_ec944_row19_col1, #T_ec944_row20_col1 {
#   background-color: blue;
# }
# #T_ec944_row21_col1, #T_ec944_row22_col1, #T_ec944_row23_col1, #T_ec944_row24_col1 {
#   background-color: black;
# }
# </style>
# <table id="T_ec944">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec944_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_ec944_level0_col1" class="col_heading level0 col1" >Actor</th>
#       <th id="T_ec944_level0_col2" class="col_heading level0 col2" >Director</th>
#       <th id="T_ec944_level0_col3" class="col_heading level0 col3" >Box Office</th>
#       <th id="T_ec944_level0_col4" class="col_heading level0 col4" >Budget</th>
#       <th id="T_ec944_level0_col5" class="col_heading level0 col5" >Bond Actor Salary</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Film</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec944_level0_row0" class="row_heading level0 row0" >Dr. No</th>
#       <td id="T_ec944_row0_col0" class="data row0 col0" >1962</td>
#       <td id="T_ec944_row0_col1" class="data row0 col1" >Sean Connery</td>
#       <td id="T_ec944_row0_col2" class="data row0 col2" >Terence Young</td>
#       <td id="T_ec944_row0_col3" class="data row0 col3" >448.800000</td>
#       <td id="T_ec944_row0_col4" class="data row0 col4" >7.000000</td>
#       <td id="T_ec944_row0_col5" class="data row0 col5" >0.600000</td>
#     </tr>
#     <tr>
#       <th id="T_ec944_level0_row1" class="row_heading level0 row1" >From Russia with Love</th>
#       <td id="T_ec944_row1_col0" class="data row1 col0" >1963</td>
#       <td id="T_ec944_row1_col1" class="data row1 col1" >Sean Connery</td>
#       <td id="T_ec944_row1_col2" class="data row1 col2" >Terence Young</td>
#       <td id="T_ec944_row1_col3" class="data row1 col3" >543.800000</td>
#       <td id="T_ec944_row1_col4" class="data row1 col4" >12.600000</td>
#       <td id="T_ec944_row1_col5" class="data row1 col5" >1.600000</td>
#     </tr>
#     <tr>
#       <th id="T_ec944_level0_row2" class="row_heading level0 row2" >Goldfinger</th>
#       <td id="T_ec944_row2_col0" class="data row2 col0" >1964</td>
#       <td id="T_ec944_row2_col1" class="data row2 col1" >Sean Connery</td>
#       <td id="T_ec944_row2_col2" class="data row2 col2" >Guy Hamilton</td>
#       <td id="T_ec944_row2_col3" class="data row2 col3" >820.400000</td>
#       <td id="T_ec944_row2_col4" class="data row2 col4" >18.600000</td>
#       <td id="T_ec944_row2_col5" class="data row2 col5" >3.200000</td>
#     </tr>
#     <tr>
#       <th id="T_ec944_level0_row3" class="row_heading level0 row3" >Thunderball</th>
#       <td id="T_ec944_row3_col0" class="data row3 col0" >1965</td>
#       <td id="T_ec944_row3_col1" class="data row3 col1" >Sean Connery</td>
#       <td id="T_ec944_row3_col2" class="data row3 col2" >Terence Young</td>
#       <td id="T_ec944_row3_col3" class="data row3 col3" >848.100000</td>
#       <td id="T_ec944_row3_col4" class="data row3 col4" >41.900000</td>
#       <td id="T_ec944_row3_col5" class="data row3 col5" >4.700000</td>
#     </tr>
#     <tr>
#       <th id="T_ec944_level0_row4" class="row_heading level0 row4" >You Only Live Twice</th>
#       <td id="T_ec944_row4_col0" class="data row4 col0" >1967</td>
#       <td id="T_ec944_row4_col1" class="data row4 col1" >Sean Connery</td>
#       <td id="T_ec944_row4_col2" class="data row4 col2" >Lewis Gilbert</td>
#       <td id="T_ec944_row4_col3" class="data row4 col3" >514.200000</td>
#       <td id="T_ec944_row4_col4" class="data row4 col4" >59.900000</td>
#       <td id="T_ec944_row4_col5" class="data row4 col5" >4.400000</td>
#     </tr>
#     <tr>
#       <th id="T_ec944_level0_row5" class="row_heading level0 row5" >On Her Majesty's Secret Service</th>
#       <td id="T_ec944_row5_col0" class="data row5 col0" >1969</td>
#       <td id="T_ec944_row5_col1" class="data row5 col1" >George Lazenby</td>
#       <td id="T_ec944_row5_col2" class="data row5 col2" >Peter R. Hunt</td>
#       <td id="T_ec944_row5_col3" class="data row5 col3" >291.500000</td>
#       <td id="T_ec944_row5_col4" class="data row5 col4" >37.300000</td>
#       <td id="T_ec944_row5_col5" class="data row5 col5" >0.600000</td>
#     </tr>
#     <tr>
#       <th id="T_ec944_level0_row6" class="row_heading level0 row6" >Diamonds Are Forever</th>
#       <td id="T_ec944_row6_col0" class="data row6 col0" >1971</td>
#       <td id="T_ec944_row6_col1" class="data row6 col1" >Sean Connery</td>
#       <td id="T_ec944_row6_col2" class="data row6 col2" >Guy Hamilton</td>
#       <td id="T_ec944_row6_col3" class="data row6 col3" >442.500000</td>
#       <td id="T_ec944_row6_col4" class="data row6 col4" >34.700000</td>
#       <td id="T_ec944_row6_col5" class="data row6 col5" >5.800000</td>
#     </tr>
#     <tr>
#       <th id="T_ec944_level0_row7" class="row_heading level0 row7" >Live and Let Die</th>
#       <td id="T_ec944_row7_col0" class="data row7 col0" >1973</td>
#       <td id="T_ec944_row7_col1" class="data row7 col1" >Roger Moore</td>
#       <td id="T_ec944_row7_col2" class="data row7 col2" >Guy Hamilton</td>
#       <td id="T_ec944_row7_col3" class="data row7 col3" >460.300000</td>
#       <td id="T_ec944_row7_col4" class="data row7 col4" >30.800000</td>
#       <td id="T_ec944_row7_col5" class="data row7 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec944_level0_row8" class="row_heading level0 row8" >The Man with the Golden Gun</th>
#       <td id="T_ec944_row8_col0" class="data row8 col0" >1974</td>
#       <td id="T_ec944_row8_col1" class="data row8 col1" >Roger Moore</td>
#       <td id="T_ec944_row8_col2" class="data row8 col2" >Guy Hamilton</td>
#       <td id="T_ec944_row8_col3" class="data row8 col3" >334.000000</td>
#       <td id="T_ec944_row8_col4" class="data row8 col4" >27.700000</td>
#       <td id="T_ec944_row8_col5" class="data row8 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec944_level0_row9" class="row_heading level0 row9" >The Spy Who Loved Me</th>
#       <td id="T_ec944_row9_col0" class="data row9 col0" >1977</td>
#       <td id="T_ec944_row9_col1" class="data row9 col1" >Roger Moore</td>
#       <td id="T_ec944_row9_col2" class="data row9 col2" >Lewis Gilbert</td>
#       <td id="T_ec944_row9_col3" class="data row9 col3" >533.000000</td>
#       <td id="T_ec944_row9_col4" class="data row9 col4" >45.100000</td>
#       <td id="T_ec944_row9_col5" class="data row9 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec944_level0_row10" class="row_heading level0 row10" >Moonraker</th>
#       <td id="T_ec944_row10_col0" class="data row10 col0" >1979</td>
#       <td id="T_ec944_row10_col1" class="data row10 col1" >Roger Moore</td>
#       <td id="T_ec944_row10_col2" class="data row10 col2" >Lewis Gilbert</td>
#       <td id="T_ec944_row10_col3" class="data row10 col3" >535.000000</td>
#       <td id="T_ec944_row10_col4" class="data row10 col4" >91.500000</td>
#       <td id="T_ec944_row10_col5" class="data row10 col5" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_ec944_level0_row11" class="row_heading level0 row11" >For Your Eyes Only</th>
#       <td id="T_ec944_row11_col0" class="data row11 col0" >1981</td>
#       <td id="T_ec944_row11_col1" clas

# %% [markdown]
# ### The `.apply()` Method

# %% [markdown]
# Applies a function to the DataFrame row-wise or column-wise.

# %%
def highlight_rows(row):
    actor = row["Actor"]

    bcolor = {
        "Roger Moore": "green",
        "Sean Connery": "red",
        "Pierce Brosnan": "blue",
        "Daniel Craig": "black",
        "Timothy Dalton": "BlueViolet",
        "George Lazenby": "CornflowerBlue",
    }

    if actor in bcolor.keys():
        return [f"background-color: {bcolor[actor]}; font-family: Ariel;" for r in row]
    return ""


bond.style.apply(highlight_rows, axis=1)
# Out:
# <style type="text/css">
# #T_16523_row0_col0, #T_16523_row0_col1, #T_16523_row0_col2, #T_16523_row0_col3, #T_16523_row0_col4, #T_16523_row0_col5, #T_16523_row1_col0, #T_16523_row1_col1, #T_16523_row1_col2, #T_16523_row1_col3, #T_16523_row1_col4, #T_16523_row1_col5, #T_16523_row2_col0, #T_16523_row2_col1, #T_16523_row2_col2, #T_16523_row2_col3, #T_16523_row2_col4, #T_16523_row2_col5, #T_16523_row3_col0, #T_16523_row3_col1, #T_16523_row3_col2, #T_16523_row3_col3, #T_16523_row3_col4, #T_16523_row3_col5, #T_16523_row4_col0, #T_16523_row4_col1, #T_16523_row4_col2, #T_16523_row4_col3, #T_16523_row4_col4, #T_16523_row4_col5, #T_16523_row6_col0, #T_16523_row6_col1, #T_16523_row6_col2, #T_16523_row6_col3, #T_16523_row6_col4, #T_16523_row6_col5, #T_16523_row12_col0, #T_16523_row12_col1, #T_16523_row12_col2, #T_16523_row12_col3, #T_16523_row12_col4, #T_16523_row12_col5 {
#   background-color: red;
#   font-family: Ariel;
# }
# #T_16523_row5_col0, #T_16523_row5_col1, #T_16523_row5_col2, #T_16523_row5_col3, #T_16523_row5_col4, #T_16523_row5_col5 {
#   background-color: CornflowerBlue;
#   font-family: Ariel;
# }
# #T_16523_row7_col0, #T_16523_row7_col1, #T_16523_row7_col2, #T_16523_row7_col3, #T_16523_row7_col4, #T_16523_row7_col5, #T_16523_row8_col0, #T_16523_row8_col1, #T_16523_row8_col2, #T_16523_row8_col3, #T_16523_row8_col4, #T_16523_row8_col5, #T_16523_row9_col0, #T_16523_row9_col1, #T_16523_row9_col2, #T_16523_row9_col3, #T_16523_row9_col4, #T_16523_row9_col5, #T_16523_row10_col0, #T_16523_row10_col1, #T_16523_row10_col2, #T_16523_row10_col3, #T_16523_row10_col4, #T_16523_row10_col5, #T_16523_row11_col0, #T_16523_row11_col1, #T_16523_row11_col2, #T_16523_row11_col3, #T_16523_row11_col4, #T_16523_row11_col5, #T_16523_row13_col0, #T_16523_row13_col1, #T_16523_row13_col2, #T_16523_row13_col3, #T_16523_row13_col4, #T_16523_row13_col5, #T_16523_row14_col0, #T_16523_row14_col1, #T_16523_row14_col2, #T_16523_row14_col3, #T_16523_row14_col4, #T_16523_row14_col5 {
#   background-color: green;
#   font-family: Ariel;
# }
# #T_16523_row15_col0, #T_16523_row15_col1, #T_16523_row15_col2, #T_16523_row15_col3, #T_16523_row15_col4, #T_16523_row15_col5, #T_16523_row16_col0, #T_16523_row16_col1, #T_16523_row16_col2, #T_16523_row16_col3, #T_16523_row16_col4, #T_16523_row16_col5 {
#   background-color: BlueViolet;
#   font-family: Ariel;
# }
# #T_16523_row17_col0, #T_16523_row17_col1, #T_16523_row17_col2, #T_16523_row17_col3, #T_16523_row17_col4, #T_16523_row17_col5, #T_16523_row18_col0, #T_16523_row18_col1, #T_16523_row18_col2, #T_16523_row18_col3, #T_16523_row18_col4, #T_16523_row18_col5, #T_16523_row19_col0, #T_16523_row19_col1, #T_16523_row19_col2, #T_16523_row19_col3, #T_16523_row19_col4, #T_16523_row19_col5, #T_16523_row20_col0, #T_16523_row20_col1, #T_16523_row20_col2, #T_16523_row20_col3, #T_16523_row20_col4, #T_16523_row20_col5 {
#   background-color: blue;
#   font-family: Ariel;
# }
# #T_16523_row21_col0, #T_16523_row21_col1, #T_16523_row21_col2, #T_16523_row21_col3, #T_16523_row21_col4, #T_16523_row21_col5, #T_16523_row22_col0, #T_16523_row22_col1, #T_16523_row22_col2, #T_16523_row22_col3, #T_16523_row22_col4, #T_16523_row22_col5, #T_16523_row23_col0, #T_16523_row23_col1, #T_16523_row23_col2, #T_16523_row23_col3, #T_16523_row23_col4, #T_16523_row23_col5, #T_16523_row24_col0, #T_16523_row24_col1, #T_16523_row24_col2, #T_16523_row24_col3, #T_16523_row24_col4, #T_16523_row24_col5 {
#   background-color: black;
#   font-family: Ariel;
# }
# </style>
# <table id="T_16523">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16523_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_16523_level0_col1" class="col_heading level0 col1" >Actor</th>
#       <th id="T_16523_level0_col2" class="col_heading level0 col2" >Director</th>
#       <th id="T_16523_level0_col3" class="col_heading level0 col3" >Box Office</th>
#       <th id="T_16523_level0_col4" class="col_heading level0 col4" >Budget</th>
#       <th id="T_16523_level0_col5" class="col_heading level0 col5" >Bond Actor Salary</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Film</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16523_level0_row0" class="row_heading level0 row0" >Dr. No</th>
#       <td id="T_16523_row0_col0" class="data row0 col0" >1962</td>
#       <td id="T_16523_row0_col1" class="data row0 col1" >Sean Connery</td>
#       <td id="T_16523_row0_col2" class="data row0 col2" >Terence Young</td>
#       <td id="T_16523_row0_col3" class="data row0 col3" >448.800000</td>
#       <td id="T_16523_row0_col4" class="data row0 col4" >7.000000</td>
#       <td id="T_16523_row0_col5" class="data row0 col5" >0.600000</td>
#     </tr>
#     <tr>
#       <th id="T_16523_level0_row1" class="row_heading level0 row1" >From Russia with Love</th>
#       <td id="T_16523_row1_col0" class="data row1 col0" >1963</td>
#       <td id="T_16523_row1_col1" class="data row1 col1" >Sean Connery</td>
#       <td id="T_16523_row1_col2" class="data row1 col2" >Terence Young</td>
#       <td id="T_16523_row1_col3" class="data row1 col3" >543.800000</td>
#       <td id="T_16523_row1_col4" class="data row1 col4" >12.600000</td>
#       <td id="T_16523_row1_col5" class="data row1 col5" >1.600000</td>
#     </tr>
#     <tr>
#       <th id="T_16523_level0_row2" class="row_heading level0 row2" >Goldfinger</th>
#       <td id="T_16523_row2_col0" class="data row2 col0" >1964</td>
#       <td id="T_16523_row2_col1" class="data row2 col1" >Sean Connery</td>
#       <td id="T_16523_row2_col2" class="data row2 col2" >Guy Hamilton</td>
#       <td id="T_16523_row2_col3" class="data row2 col3" >820.400000</td>
#       <td id="T_16523_row2_col4" class="data row2 col4" >18.600000</td>
#       <td id="T_16523_row2_col5" class="data row2 col5" >3.200000</td>
#     </tr>
#     <tr>
#       <th id="T_16523_level0_row3" class="row_heading level0 row3" >Thunderball</th>
#       <td id="T_16523_row3_col0" class="data row3 col0" >1965</td>
#       <td id="T_16523_row3_col1" class="data row3 col1" >Sean Connery</td>
#       <td id="T_16523_row3_col2" class="data row3 col2" >Terence Young</td>
#       <td id="T_16523_row3_col3" class="data row3 col3" >848.100000</td>
#       <td id="T_16523_row3_col4" class="data row3 col4" >41.900000</td>
#       <td id="T_16523_row3_col5" class="data row3 col5" >4.700000</td>
#     </tr>
#     <tr>
#       <th id="T_16523_level0_row4" class="row_heading level0 row4" >You Only Live Twice</th>
#       <td id="T_16523_row4_col0" class="data row4 col0" >1967</td>
#       <td id="T_16523_row4_col1" class="data row4 col1" >Sean Connery</td>
#       <td id="T_16523_row4_col2" class="data row4 col2" >Lewis Gilbert</td>
#       <td id="T_16523_row4_col3" class="data row4 col3" >514.200000</td>
#       <td id="T_16523_row4_col4" class="data row4 col4" >59.900000</td>
#       <td id="T_16523_row4_col5" class="data row4 col5" >4.400000</td>
#     </tr>
#     <tr>
#       <th id="T_16523_level0_row5" class="row_heading level0 row5" >On Her Majesty's Secret Service</th>
#       <td id="T_16523_row5_col0" class="data row5 col0" >1969</td>
#       <td id="T_16523_row5_col1" class="data row5 col1" >George Lazenby</td>
#       <td id="T_16523_row5_col2" class="data row5 col2" >Peter R. Hunt</td>
#       <td id="T_16523_row5_col3" class="data row5 col3" >291.500000</td>
#       <td id="T_16523_row5_col4" class="data row5 col4" >37.300000</td>
#       <td id="T_16523_row5_col5" class="data row5 col5" >0.600000</td>
#     </tr>
#     <tr>
#       <th id="T_16523_level0_row6" class="row_heading level0 row6" >Diamonds Are Forever</th>
#       <td id="T_16523_row6_col0" class="data row6 col0" >1971</td>
#       <td id="T_16523_row6_col1" class="data row6 col1" >Sean Connery</td>
#       <td id="T_16523_row6_col2" class="data row6 col2" >Guy Hamilton</td>
#       <td id="T_16523_row6_col3" class="data ro
